# %%
# Importing necessary Libraries
import numpy as np 
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\navee\OneDrive\Desktop\Sample - Superstore.xls")
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Value Counts Function

# %%
data['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
data['Category'].value_counts(normalize=True)
# Out:
# Office Supplies    0.602962
# Furniture          0.212227
# Technology         0.184811
# Name: Category, dtype: float64

# %%
data['Sub-Category'].value_counts() # normalize is used to identify the frequency of a each value in that column
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
 # normalize is used to identify the frequency of a each value in that column
data['Sub-Category'].value_counts(normalize=True)
# Out:
# Binders        0.152391
# Paper          0.137082
# Furnishings    0.095757
# Phones         0.088953
# Storage        0.084651
# Art            0.079648
# Accessories    0.077547
# Chairs         0.061737
# Appliances     0.046628
# Labels         0.036422
# Tables         0.031919
# Envelopes      0.025415
# Bookcases      0.022814
# Fasteners      0.021713
# Supplies       0.019011
# Machines       0.011507
# Copiers        0.006804
# Name: Sub-Category, dtype: float64

# %% [markdown]
# # Where Function

# %%
# where function only returns a subset of a data frame or a series where condition is satisfied  
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data[data.where(data['Quantity']>5,other=0).any(1)]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 7          8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 10        11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 16        17  CA-2014-105893 2014-11-11 2014-11-18  Standard Class
# 21        22  CA-2016-137330 2016-12-09 2016-12-13  Standard Class
# ...      ...             ...        ...        ...             ...
# 9974    9975  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9977    9978  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9979    9980  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9982    9983  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9984    9985  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
#
#      Customer ID     Customer Name      Segment        Country          City  \
# 5       BH-11710   Brosina Hoffman     Consumer  United States   Los Angeles
# ...

# %%
f1 = data['Quantity']>5 
f2 = data['Category'] =='Furniture'
data[data.where(f1 & f2,other=0).any(1)]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 10        11  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 27        28  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# 72        73  US-2015-134026 2015-04-26 2015-05-02  Standard Class
# 96        97  CA-2017-161018 2017-11-09 2017-11-11    Second Class
# ...      ...             ...        ...        ...             ...
# 9844    9845  CA-2014-163867 2014-06-03 2014-06-06     First Class
# 9857    9858  CA-2015-164301 2015-03-26 2015-03-30  Standard Class
# 9879    9880  CA-2016-122581 2016-08-21 2016-08-25  Standard Class
# 9905    9906  US-2015-129007 2015-09-13 2015-09-15     First Class
# 9947    9948  CA-2017-121559 2017-06-01 2017-06-03    Second Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# 5       BH-11710   Brosina Hoffman     Consumer  United States    Los Angeles
# ...

# %% [markdown]
# # Isin Function

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
data[data['Sub-Category'].isin(['Furnishings','Bookcases'])]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 27        28  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# 29        30  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# 36        37  CA-2016-117590 2016-12-08 2016-12-10     First Class
# ...      ...             ...        ...        ...             ...
# 9938    9939  CA-2016-169824 2016-12-12 2016-12-17  Standard Class
# 9962    9963  CA-2015-168088 2015-03-19 2015-03-22     First Class
# 9964    9965  CA-2016-146374 2016-12-05 2016-12-10    Second Class
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# 0       CG-12520       Claire Gute     Consumer  United States      Henderson
# ...

# %%
data[data[['Region','Segment']].isin({'Region':['South','East'],'Segment':['Consumer']}).any(1)]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name   Segment        Country             City  \
# 0       CG-12520       Claire Gute  Consumer  United States        Henderson
# ...

# %% [markdown]
# # Cut and qcut

# %%
data['disc_bins'] = pd.cut(data['Discount'],bins=[0.1,0.3,0.4,0.6,0.7,1])

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
labels = ['a','b','c','d','e']
data['disc_bins'] = pd.cut(data['Discount'],bins=[0.1,0.3,0.4,0.6,0.7,1],labels=labels)

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
pd.qcut(data['Quantity'],5)
# Out:
# 0       (0.999, 2.0]
# 1         (2.0, 3.0]
# 2       (0.999, 2.0]
# 3         (4.0, 5.0]
# 4       (0.999, 2.0]
#             ...
# 9989      (2.0, 3.0]
# 9990    (0.999, 2.0]
# 9991    (0.999, 2.0]
# 9992      (3.0, 4.0]
# 9993    (0.999, 2.0]
# Name: Quantity, Length: 9994, dtype: category
# Categories (5, interval[float64, right]): [(0.999, 2.0] < (2.0, 3.0] < (3.0, 4.0] < (4.0, 5.0] < (5.0, 14.0]]

# %% [markdown]
# # Groupby Function

# %%
data.groupby('Category')['Sales'].sum()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
data.groupby('Category')['Quantity'].sum()
# Out:
# Category
# Furniture           8028
# Office Supplies    22906
# Technology          6939
# Name: Quantity, dtype: int64

# %%
data.groupby('Category')['Sales'].agg(['sum','mean','count'])
# Out:
#                          sum        mean  count
# Category
# Furniture        741999.7953  349.834887   2121
# Office Supplies  719047.0320  119.324101   6026
# Technology       836154.0330  452.709276   1847

# %%
data.groupby('Category').agg({'Sales':'sum','Quantity':'mean'})
# Out:
#                        Sales  Quantity
# Category
# Furniture        741999.7953  3.785007
# Office Supplies  719047.0320  3.801195
# Technology       836154.0330  3.756903

# %% [markdown]
# # Pivot Table

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ... Region  \
# 0      Claire Gute   Consumer  United States        Henderson  ...  South
# 1      Claire Gute   Consumer  United States        Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...   West
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...  South
#
#         Product ID         Category Sub-Category  \
# ...

# %%
data.pivot_table(index='Sub-Category',values='Sales')
# Out:
#                     Sales
# Sub-Category
# Accessories    215.974604
# Appliances     230.755710
# Art             34.068834
# Binders        133.560560
# Bookcases      503.859633
# Chairs         532.332420
# Copiers       2198.941618
# Envelopes       64.867724
# Fasteners       13.936774
# Furnishings     95.825668
# Labels          34.303055
# Machines      1645.553313
# Paper           57.284092
# Phones         371.211534
# Storage        264.590553
# Supplies       245.650200
# Tables         648.794771

# %%
data.pivot_table(index='Sub-Category',values='Sales',aggfunc='sum')
# Out:
#                     Sales
# Sub-Category
# Accessories   167380.3180
# Appliances    107532.1610
# Art            27118.7920
# Binders       203412.7330
# Bookcases     114879.9963
# Chairs        328449.1030
# Copiers       149528.0300
# Envelopes      16476.4020
# Fasteners       3024.2800
# Furnishings    91705.1640
# Labels         12486.3120
# Machines      189238.6310
# Paper          78479.2060
# Phones        330007.0540
# Storage       223843.6080
# Supplies       46673.5380
# Tables        206965.5320

# %%
data.groupby('Sub-Category')['Sales'].sum()
# Out:
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27118.7920
# Binders        203412.7330
# Bookcases      114879.9963
# Chairs         328449.1030
# Copiers        149528.0300
# Envelopes       16476.4020
# Fasteners        3024.2800
# Furnishings     91705.1640
# Labels          12486.3120
# Machines       189238.6310
# Paper           78479.2060
# Phones         330007.0540
# Storage        223843.6080
# Supplies        46673.5380
# Tables         206965.5320
# Name: Sales, dtype: float64

# %%
# Pivot table is like of groupby function 
data.pivot_table(index=['Sub-Category'],values=['Sales','Profit'],aggfunc=['sum','mean'])
# Out:
#                      sum                     mean
#                   Profit        Sales      Profit        Sales
# Sub-Category
# Accessories   41936.6357  167380.3180   54.111788   215.974604
# Appliances    18138.0054  107532.1610   38.922758   230.755710
# Art            6527.7870   27118.7920    8.200737    34.068834
# Binders       30221.7633  203412.7330   19.843574   133.560560
# Bookcases     -3472.5560  114879.9963  -15.230509   503.859633
# Chairs        26590.1663  328449.1030   43.095894   532.332420
# Copiers       55617.8249  149528.0300  817.909190  2198.941618
# Envelopes      6964.1767   16476.4020   27.418019    64.867724
# Fasteners       949.5182    3024.2800    4.375660    13.936774
# Furnishings   13059.1436   91705.1640   13.645918    95.825668
# Labels         5546.2540   12486.3120   15.236962    34.303055
# Machines       3384.7569  189238.6310   29.432669  1645.553313
# Paper         34053.5693   78479.2060   24.856620    57.284092
# ...

# %% [markdown]
# # nlargest and nsmallest

# %%
# these are like to replace sort values function in data frame and for also to max functions
data['Profit'].nlargest(10)
# Out:
# 6826    8399.9760
# 8153    6719.9808
# 4190    5039.9856
# 9039    4946.3700
# 4098    4630.4755
# 2623    3919.9888
# 509     3177.4750
# 8488    2799.9840
# 7666    2591.9568
# 6520    2504.2216
# Name: Profit, dtype: float64

# %%
data.nlargest(5,'Profit')
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 6826    6827  CA-2016-118689 2016-10-02 2016-10-09  Standard Class
# 8153    8154  CA-2017-140151 2017-03-23 2017-03-25     First Class
# 4190    4191  CA-2017-166709 2017-11-17 2017-11-22  Standard Class
# 9039    9040  CA-2016-117121 2016-12-17 2016-12-21  Standard Class
# 4098    4099  CA-2014-116904 2014-09-23 2014-09-28  Standard Class
#
#      Customer ID  Customer Name    Segment        Country         City  ...  \
# 6826    TC-20980   Tamara Chand  Corporate  United States    Lafayette  ...
# 8153    RB-19360   Raymond Buch   Consumer  United States      Seattle  ...
# 4190    HL-15040   Hunter Lopez   Consumer  United States       Newark  ...
# 9039    AB-10105  Adrian Barton   Consumer  United States      Detroit  ...
# 4098    SC-20095   Sanjit Chand   Consumer  United States  Minneapolis  ...
#
#        Region       Product ID         Category Sub-Category  \
# ...

# %%
data['Sales'].nsmallest(5)
# Out:
# 4101    0.444
# 9292    0.556
# 8658    0.836
# 4711    0.852
# 2106    0.876
# Name: Sales, dtype: float64

# %%
data.nlargest(5,'Sales')
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317 2014-03-18 2014-03-23  Standard Class
# 6826    6827  CA-2016-118689 2016-10-02 2016-10-09  Standard Class
# 8153    8154  CA-2017-140151 2017-03-23 2017-03-25     First Class
# 2623    2624  CA-2017-127180 2017-10-22 2017-10-24     First Class
# 4190    4191  CA-2017-166709 2017-11-17 2017-11-22  Standard Class
#
#      Customer ID Customer Name      Segment        Country           City  \
# 2697    SM-20320   Sean Miller  Home Office  United States   Jacksonville
# 6826    TC-20980  Tamara Chand    Corporate  United States      Lafayette
# 8153    RB-19360  Raymond Buch     Consumer  United States        Seattle
# 2623    TA-21385  Tom Ashbrook  Home Office  United States  New York City
# 4190    HL-15040  Hunter Lopez     Consumer  United States         Newark
#
#       ...   Region       Product ID    Category Sub-Category  \
# ...

# %%
data.nlargest(5,['Profit','Sales'])
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 6826    6827  CA-2016-118689 2016-10-02 2016-10-09  Standard Class
# 8153    8154  CA-2017-140151 2017-03-23 2017-03-25     First Class
# 4190    4191  CA-2017-166709 2017-11-17 2017-11-22  Standard Class
# 9039    9040  CA-2016-117121 2016-12-17 2016-12-21  Standard Class
# 4098    4099  CA-2014-116904 2014-09-23 2014-09-28  Standard Class
#
#      Customer ID  Customer Name    Segment        Country         City  ...  \
# 6826    TC-20980   Tamara Chand  Corporate  United States    Lafayette  ...
# 8153    RB-19360   Raymond Buch   Consumer  United States      Seattle  ...
# 4190    HL-15040   Hunter Lopez   Consumer  United States       Newark  ...
# 9039    AB-10105  Adrian Barton   Consumer  United States      Detroit  ...
# 4098    SC-20095   Sanjit Chand   Consumer  United States  Minneapolis  ...
#
#        Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Query Function

# %%
data.query('Sales>=10000')
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2623    2624  CA-2017-127180 2017-10-22 2017-10-24     First Class
# 2697    2698  CA-2014-145317 2014-03-18 2014-03-23  Standard Class
# 4190    4191  CA-2017-166709 2017-11-17 2017-11-22  Standard Class
# 6826    6827  CA-2016-118689 2016-10-02 2016-10-09  Standard Class
# 8153    8154  CA-2017-140151 2017-03-23 2017-03-25     First Class
#
#      Customer ID Customer Name      Segment        Country           City  \
# 2623    TA-21385  Tom Ashbrook  Home Office  United States  New York City
# 2697    SM-20320   Sean Miller  Home Office  United States   Jacksonville
# 4190    HL-15040  Hunter Lopez     Consumer  United States         Newark
# 6826    TC-20980  Tamara Chand    Corporate  United States      Lafayette
# 8153    RB-19360  Raymond Buch     Consumer  United States        Seattle
#
#       ...   Region       Product ID    Category Sub-Category  \
# ...

# %%
data.query('Sales>=10000 and Quantity>5')
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317 2014-03-18 2014-03-23  Standard Class
#
#      Customer ID Customer Name      Segment        Country          City  ...  \
# 2697    SM-20320   Sean Miller  Home Office  United States  Jacksonville  ...
#
#      Region       Product ID    Category Sub-Category  \
# 2697  South  TEC-MA-10002412  Technology     Machines
#
#                                            Product Name     Sales Quantity  \
# 2697  Cisco TelePresence System EX90 Videoconferenci...  22638.48        6
#
#       Discount     Profit  disc_bins
# 2697       0.5 -1811.0784          c
#
# [1 rows x 22 columns]

# %% [markdown]
# # Str Functions

# %%
# str lower 
data['Region'].str.lower()
# Out:
# 0       south
# 1       south
# 2        west
# 3       south
# 4       south
#         ...
# 9989    south
# 9990     west
# 9991     west
# 9992     west
# 9993     west
# Name: Region, Length: 9994, dtype: object

# %%
# str uppert 
data['Region'].str.upper()
# Out:
# 0       SOUTH
# 1       SOUTH
# 2        WEST
# 3       SOUTH
# 4       SOUTH
#         ...
# 9989    SOUTH
# 9990     WEST
# 9991     WEST
# 9992     WEST
# 9993     WEST
# Name: Region, Length: 9994, dtype: object

# %%
# str len 
# str uppert 
data['Region'].str.len()
# Out:
# 0       5
# 1       5
# 2       4
# 3       5
# 4       5
#        ..
# 9989    5
# 9990    4
# 9991    4
# 9992    4
# 9993    4
# Name: Region, Length: 9994, dtype: int64

# %%
# str strip is used to remove white spaces in a string from stating and in ending 
data['Region'].str.strip()
# Out:
# 0       South
# 1       South
# 2        West
# 3       South
# 4       South
#         ...
# 9989    South
# 9990     West
# 9991     West
# 9992     West
# 9993     West
# Name: Region, Length: 9994, dtype: object

# %%
# str split 
data['Ship Date']
# Out:
# 0      2016-11-11
# 1      2016-11-11
# 2      2016-06-16
# 3      2015-10-18
# 4      2015-10-18
#           ...
# 9989   2014-01-23
# 9990   2017-03-03
# 9991   2017-03-03
# 9992   2017-03-03
# 9993   2017-05-09
# Name: Ship Date, Length: 9994, dtype: datetime64[ns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
data['Ship Date'] = data['Ship Date'].astype('str')

# %%
data['Ship Date'].dtype
# Out:
# dtype('O')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
data[['Year','Month','Day']] = data['Ship Date'].str.split('-',expand=True)

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Sub-Category                                       Product Name     Sales  \
# ...

# %%
data['Order ID'].str.split('-',expand=True)
# Out:
#        0     1       2
# 0     CA  2016  152156
# 1     CA  2016  152156
# 2     CA  2016  138688
# 3     US  2015  108966
# 4     US  2015  108966
# ...   ..   ...     ...
# 9989  CA  2014  110422
# 9990  CA  2017  121258
# 9991  CA  2017  121258
# 9992  CA  2017  121258
# 9993  CA  2017  119914
#
# [9994 rows x 3 columns]

# %%
data['Customer ID'].str.split('-',expand=True)
# Out:
#        0      1
# 0     CG  12520
# 1     CG  12520
# 2     DV  13045
# 3     SO  20335
# 4     SO  20335
# ...   ..    ...
# 9989  TB  21400
# 9990  DB  13060
# 9991  DB  13060
# 9992  DB  13060
# 9993  CC  12220
#
# [9994 rows x 2 columns]

# %%
# str contains 
data[data['Ship Mode'].str.contains('Standard')]
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 3          4  US-2015-108966 2015-10-11  2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11  2015-10-18  Standard Class
# 5          6  CA-2014-115812 2014-06-09  2014-06-14  Standard Class
# 6          7  CA-2014-115812 2014-06-09  2014-06-14  Standard Class
# 7          8  CA-2014-115812 2014-06-09  2014-06-14  Standard Class
# ...      ...             ...        ...         ...             ...
# 9987    9988  CA-2017-163629 2017-11-17  2017-11-21  Standard Class
# 9988    9989  CA-2017-163629 2017-11-17  2017-11-21  Standard Class
# 9990    9991  CA-2017-121258 2017-02-26  2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26  2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26  2017-03-03  Standard Class
#
#      Customer ID    Customer Name    Segment        Country             City  \
# ...

# %%
# str contains 
data[data['Sub-Category'].str.contains('Tables')]
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 3          4  US-2015-108966 2015-10-11  2015-10-18  Standard Class
# 10        11  CA-2014-115812 2014-06-09  2014-06-14  Standard Class
# 24        25  CA-2015-106320 2015-09-25  2015-09-30  Standard Class
# 117      118  CA-2015-110457 2015-03-02  2015-03-06  Standard Class
# 125      126  US-2014-134614 2014-09-20  2014-09-25  Standard Class
# ...      ...             ...        ...         ...             ...
# 9857    9858  CA-2015-164301 2015-03-26  2015-03-30  Standard Class
# 9899    9900  US-2014-117380 2014-03-28  2014-04-03  Standard Class
# 9937    9938  CA-2016-164889 2016-06-03  2016-06-06    Second Class
# 9955    9956  CA-2015-141593 2015-12-14  2015-12-16    Second Class
# 9980    9981  US-2015-151435 2015-09-06  2015-09-09    Second Class
#
#      Customer ID    Customer Name      Segment        Country  \
# 3       SO-20335   Sean O'Donnell     Consumer  United States
# ...

# %%
# str contains  work for sub string contains a string value
data[data['Product Name'].str.contains('Tables')]
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 10        11  CA-2014-115812 2014-06-09  2014-06-14  Standard Class
# 117      118  CA-2015-110457 2015-03-02  2015-03-06  Standard Class
# 125      126  US-2014-134614 2014-09-20  2014-09-25  Standard Class
# 201      202  CA-2014-133690 2014-08-03  2014-08-05     First Class
# 226      227  CA-2015-163055 2015-08-09  2015-08-16  Standard Class
# ...      ...             ...        ...         ...             ...
# 9639    9640  CA-2015-116638 2015-01-28  2015-01-31    Second Class
# 9746    9747  CA-2017-137505 2017-11-24  2017-11-24        Same Day
# 9756    9757  CA-2017-113705 2017-03-27  2017-03-29    Second Class
# 9899    9900  US-2014-117380 2014-03-28  2014-04-03  Standard Class
# 9937    9938  CA-2016-164889 2016-06-03  2016-06-06    Second Class
#
#      Customer ID    Customer Name      Segment        Country         City  \
# ...

# %%
# Str replace 
data['Country'] = data['Country'].str.replace('United States','USA')

# %%
data.head()
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment Country             City  ... Sub-Category  \
# 0      Claire Gute   Consumer     USA        Henderson  ...    Bookcases
# 1      Claire Gute   Consumer     USA        Henderson  ...       Chairs
# 2  Darrin Van Huff  Corporate     USA      Los Angeles  ...       Labels
# 3   Sean O'Donnell   Consumer     USA  Fort Lauderdale  ...       Tables
# 4   Sean O'Donnell   Consumer     USA  Fort Lauderdale  ...      Storage
#
# ...

# %%
data['Ship Mode'].str.replace('Second Class','2 Class').str.replace('Standard Class','1 C')
# Out:
# 0       2 Class
# 1       2 Class
# 2       2 Class
# 3           1 C
# 4           1 C
#          ...
# 9989    2 Class
# 9990        1 C
# 9991        1 C
# 9992        1 C
# 9993    2 Class
# Name: Ship Mode, Length: 9994, dtype: object

# %%
# str startswith 
data[data['Sub-Category'].str.startswith('B')]
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08  2016-11-11    Second Class
# 8          9  CA-2014-115812 2014-06-09  2014-06-14  Standard Class
# 13        14  CA-2016-161389 2016-12-05  2016-12-10  Standard Class
# 15        16  US-2015-118983 2015-11-22  2015-11-26  Standard Class
# 20        21  CA-2014-143336 2014-08-27  2014-09-01    Second Class
# ...      ...             ...        ...         ...             ...
# 9967    9968  CA-2017-153871 2017-12-11  2017-12-17  Standard Class
# 9968    9969  CA-2017-153871 2017-12-11  2017-12-17  Standard Class
# 9970    9971  CA-2015-103772 2015-06-28  2015-07-02  Standard Class
# 9978    9979  US-2016-103674 2016-12-06  2016-12-10  Standard Class
# 9979    9980  US-2016-103674 2016-12-06  2016-12-10  Standard Class
#
#      Customer ID       Customer Name      Segment Country           City  ...  \
# ...

# %%
# str startswith 
data[data['Sub-Category'].str.endswith('s')]
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08  2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08  2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12  2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11  2015-10-18  Standard Class
# 5          6  CA-2014-115812 2014-06-09  2014-06-14  Standard Class
# ...      ...             ...        ...         ...             ...
# 9988    9989  CA-2017-163629 2017-11-17  2017-11-21  Standard Class
# 9989    9990  CA-2014-110422 2014-01-21  2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26  2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26  2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04  2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment Country             City  ...  \
# ...

# %%
# str cat 
data['Country'].str.cat(data['City'],sep='_')
# Out:
# 0             USA_Henderson
# 1             USA_Henderson
# 2           USA_Los Angeles
# 3       USA_Fort Lauderdale
# 4       USA_Fort Lauderdale
#                ...
# 9989              USA_Miami
# 9990         USA_Costa Mesa
# 9991         USA_Costa Mesa
# 9992         USA_Costa Mesa
# 9993        USA_Westminster
# Name: Country, Length: 9994, dtype: object

# %%
# str get 
data['City'].str.get(0)
# Out:
# 0       H
# 1       H
# 2       L
# 3       F
# 4       F
#        ..
# 9989    M
# 9990    C
# 9991    C
# 9992    C
# 9993    W
# Name: City, Length: 9994, dtype: object

# %%
# str get 
data['City'].str.get(-1)
# Out:
# 0       n
# 1       n
# 2       s
# 3       e
# 4       e
#        ..
# 9989    i
# 9990    a
# 9991    a
# 9992    a
# 9993    r
# Name: City, Length: 9994, dtype: object

# %%
data['Customer Name'].str.split(' ').str.get(0)
# Out:
# 0       Claire
# 1       Claire
# 2       Darrin
# 3         Sean
# 4         Sean
#          ...
# 9989       Tom
# 9990      Dave
# 9991      Dave
# 9992      Dave
# 9993     Chris
# Name: Customer Name, Length: 9994, dtype: object

# %%
data['Customer Name'].str.split(' ').str.get(1)
# Out:
# 0               Gute
# 1               Gute
# 2                Van
# 3          O'Donnell
# 4          O'Donnell
#             ...
# 9989    Boeckenhauer
# 9990          Brooks
# 9991          Brooks
# 9992          Brooks
# 9993          Cortes
# Name: Customer Name, Length: 9994, dtype: object

# %%
# str slice 
data['Customer Name'].str.slice(0,3)
# Out:
# 0       Cla
# 1       Cla
# 2       Dar
# 3       Sea
# 4       Sea
#        ...
# 9989    Tom
# 9990    Dav
# 9991    Dav
# 9992    Dav
# 9993    Chr
# Name: Customer Name, Length: 9994, dtype: object

# %%
# str slice 
data['Customer Name'].str.slice(-3)
# Out:
# 0       ute
# 1       ute
# 2       uff
# 3       ell
# 4       ell
#        ...
# 9989    uer
# 9990    oks
# 9991    oks
# 9992    oks
# 9993    tes
# Name: Customer Name, Length: 9994, dtype: object

# %%
# str find 
data['Customer Name'].str.find('l')
# Out:
# 0        1
# 1        1
# 2       -1
# 3       12
# 4       12
#         ..
# 9989    -1
# 9990    -1
# 9991    -1
# 9992    -1
# 9993    -1
# Name: Customer Name, Length: 9994, dtype: int64

# %%
# str find 
data['Customer Name'].str.find('e')
# Out:
# 0        5
# 1        5
# 2       -1
# 3        1
# 4        1
#         ..
# 9989     6
# 9990     3
# 9991     3
# 9992     3
# 9993    10
# Name: Customer Name, Length: 9994, dtype: int64

# %%
# str find 
data['Customer Name'].str.rfind('e')
# Out:
# 0       10
# 1       10
# 2       -1
# 3       11
# 4       11
#         ..
# 9989    14
# 9990     3
# 9991     3
# 9992     3
# 9993    10
# Name: Customer Name, Length: 9994, dtype: int64
